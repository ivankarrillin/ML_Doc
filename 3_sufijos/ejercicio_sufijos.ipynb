# %% [markdown]
# # Ejercicio de sufijos
#
# Se realiza un ejercicio adicional para encontrar los sufijos más comunes en el ejercicio de las 5.000 palabras.

# %%
#función para encontrar la terminación -sufijo- más frecuente


sufijo=['']

coincidencias=[]

for i in range(len(sufijo)):
  sub=rima(sufijo[i])
  coincidencias.append(sub)


import pandas as pd
data = {'sufijos': sufijo,
        'coincidencias': coincidencias}

# Create DataFrame
df = pd.DataFrame(data)

ordenado=df.sort_values(by=['coincidencias'],ascending=False)
print(ordenado)


#gráfico de coincidencias de palabras -sufijos-
import matplotlib.pyplot as plt


fig, ax = plt.subplots()
ax.bar(sufijo, coincidencias)
ax.set_xticks(sufijo, sufijo, rotation='vertical')
plt.title('Frencuencia de sufijos')
plt.show()
# Out:
#   sufijos  coincidencias
# 0                   5000

# %%
terminacion.count('os')
# Out:
# 0
