# %% [markdown]
# # Ejercicio en Kaggle
#
# Ejercicio con la información de peliculas de marvel, obtenido de Kaggle y usando pandas. el Ejercicio con Polar se encuentra en Kaggle - Hub.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("timyep/marvel-movie-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: /root/.cache/kagglehub/datasets/timyep/marvel-movie-dataset/versions/1

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(path) if isfile(join(path, f))]
onlyfiles
# Out:
# ['Marvel_Movie_Recommendations.csv']

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv(path+"/Marvel_Movie_Recommendations.csv",encoding="latin-1")
df
# Out:
#     Id                                        Title  \
# 0    1                               Captain Marvel
# 1    2          Captain America: The Winter Soldier
# 2    3                                   Iron Man 2
# 3    4            Ant-Man and the Wasp: Quantumania
# 4    5                          The Incredible Hulk
# 5    6                            Avengers: Endgame
# 6    7  Doctor Strange in the Multiverse of Madness
# 7    8                                Black Panther
# 8    9                       Avengers: Infinity War
# 9   10                               Doctor Strange
# 10  11                         Ant-Man and the Wasp
# 11  12                                     Iron Man
# 12  13                      Guardians of the Galaxy
# 13  14                                         Thor
# 14  15                       Spider-Man: Homecoming
# 15  16               Guardians of the Galaxy Vol. 2
# 16  17               Guardians of the Galaxy Vol. 3
# ...
